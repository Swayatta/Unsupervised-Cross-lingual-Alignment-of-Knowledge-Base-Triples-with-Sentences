# %%
paraphrase-xlm-r-multilingual-v1

# %%
# !pip install -U torch
import torch
# !pip install -U transformers
# !pip install -U sentence-transformers
import transformers
from sentence_transformers import SentenceTransformer,util
import numpy as np

# %%
model = SentenceTransformer('paraphrase-xlm-r-multilingual-v1')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1014059776.0), HTML(value='')))

# %%
sentence1 = "I love dogs"
sentence2 = "मुझे कुत्ते अच्छे लगते हैं"
# encode sentences to get their embeddings
embedding1 = model.encode(sentence1, convert_to_tensor=True)
embedding2 = model.encode(sentence2, convert_to_tensor=True)
# compute similarity scores of two embeddings
cosine_scores = util.pytorch_cos_sim(embedding1, embedding2)
print("Sentence 1:", sentence1)
print("Sentence 2:", sentence2)
print("Similarity score:", cosine_scores.item())
# Out:
# Sentence 1: I love dogs
# Sentence 2: मुझे कुत्ते अच्छे लगते हैं
# Similarity score: 0.9315927028656006

# %%
sentence1 = "I love dogs"
sentence2 = "मैं गा सकता हूं"
# encode sentences to get their embeddings
embedding1 = model.encode(sentence1, convert_to_tensor=True)
embedding2 = model.encode(sentence2, convert_to_tensor=True)
# compute similarity scores of two embeddings
cosine_scores = util.pytorch_cos_sim(embedding1, embedding2)
print("Sentence 1:", sentence1)
print("Sentence 2:", sentence2)
print("Similarity score:", cosine_scores.item())
# Out:
# Sentence 1: I love dogs
# Sentence 2: मैं गा सकता हूं
# Similarity score: 0.3226677179336548
